# %%
import pymysql
import dataset
import MySQLdb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ### Test database connection using pymysql

# %%
# # Connect to the database
# connection = pymysql.connect(host='localhost',
#                              user='root',
#                              password='p4ssw0rd',
#                              database='projectblue',
#                              cursorclass=pymysql.cursors.DictCursor)

# query = "SELECT r.id, r.item_id, r.recommended, r.pros, r.cons, r.comments, r.is_verified, r.created_on, r.modified_on, i.slug, i.name FROM projectblue.reviews r join projectblue.items i on r.item_id = i.id;"
# cursor = connection.cursor()
# cursor.execute(query)
# df = pd.DataFrame(cursor.fetchall())
# df.head(10)

# %% [markdown]
# ## 1. Connect to the DB and export the items table to a Pandas DF
# ---

# %%
# manually set up a database in MySQL Workbench and run the projectblue SQL script to create the tables

# connect to the MySQL database with the corresponding credentials
db = dataset.connect('mysql://root:p4ssw0rd@127.0.0.1/projectblue')

# collect all the features from the items table from the projectblue database 
items_df = pd.DataFrame(data=db['items'])

# query and display 5 randomly selected samples from the items DF
items_df.sample(5)
# Out:
#         id              slug               name description  is_verified  \
# 1490  1906    missy-maramara     Missy Maramara                        0
# 82      84  bulaong-oscar-jr  Bulaong, Oscar Jr                        1
# 993   1309     chuidian-cara     Chuidian, Cara                        1
# 1465  1880             ramil              Ramil                        0
# 999   1315              tiro               tiro                        0
#
#                                       verification_data  created_on  \
# 1490     {"category":"LIT 13: Introduction To Fiction"}  1413612549
# 82                                                 None  1234567890
# 993   {"category":"BI 100.1: General Biology I, Labo...  1353441693
# 1465         {"category":"MA 11: Modern Mathematics I"}  1410003264
# 999                                   {"category":"hi"}  1358570002
#
#        modified_on
# 1490           NaN
# 82             NaN
# 993   1.366016e+09
# 1465           NaN
# 999            NaN

# %%
# display the DF's descriptive statistics
items_df.describe()
# Out:
#                 id  is_verified    created_on   modified_on
# count  1656.000000  1656.000000  1.656000e+03  2.220000e+02
# mean   1033.967391     0.604469  1.317807e+09  1.436405e+09
# std     648.941083     0.489112  7.634792e+07  4.240715e+07
# min       1.000000     0.000000  1.234568e+09  1.338238e+09
# 25%     415.750000     0.000000  1.234568e+09  1.438861e+09
# 50%    1118.500000     1.000000  1.340183e+09  1.447017e+09
# 75%    1596.250000     1.000000  1.382185e+09  1.464685e+09
# max    2120.000000     1.000000  1.488829e+09  1.482060e+09

# %% [markdown]
# ## 2. Build a classifier using an SVM to identify whether a comment results to a recommendation or not
# ---

# %%
# collect all the features from the reviews table from the projectblue database 
reviews_df = pd.DataFrame(data=db['reviews'])

# query and display 5 randomly selected samples from the reviews DF
reviews_df.sample(5)
# Out:
#           id  item_id  recommended  \
# 4684    5059      480            1
# 9328    9951      611            1
# 20215  21502      630            1
# 22115  23580      442            1
# 21436  22857       61            0
#
#                                                     pros  \
# 4684   Funny. Tells a lot of fun and interesting stor...
# 9328      No finals\nVery Considerate\nLiked by students
# 20215                                      knowledgeable
# 22115  He gives out a Magic Word list that is basical...
# 21436  As long as you submit homework, you get the fu...
#
#                                                     cons  \
# 4684                                                None
# 9328   Her tests are a bit hard. You really have to l...
# 20215                                unclear assignments
# 22115  Beware of his essays! If you listen in class, ...
# 21436    He loves absolute values. It is not fun at all.
#
#                                                 comments  is_verified  \
# 4684                                    You'll love him!            1
# 9328            She's nice and I learned a lot from her!            1
# 20215  may make fun of students' names based on etymo...            1
# 22115  An fairly easy prof with a lot of insights on ...            1
# 21436                        He loves australian accents            1
#
#        created_on   modified_on
# 4684   1338919240  1.339025e+09
# 9328   1351170815  1.365041e+09
# 20215  1401733555  1.439749e+09
# 22115  1414502307  1.448223e+09
# 21436  1413625216  1.447017e+09

# %%
# drop rows that have missing values
reviews_df.dropna()
# Out:
#           id  item_id  recommended  \
# 1445    1476      978            1
# 1446    1477      631            1
# 1447    1478      156            1
# 1448    1479      269            1
# 1449    1480       91            1
# ...      ...      ...          ...
# 23659  25217       48            1
# 23660  25218      503            1
# 23661  25219      291            0
# 23662  25220      156            1
# 23663  25221       14            0
#
#                                                     pros  \
# 1445                                   I heard he's good
# 1446             Easy to understand, Approachable, Jolly
# 1447   Unique approach to Philosophy. Lessons can be ...
# 1448   She really knows her stufff and teaches very c...
# 1449                   passionate\nconsiderate\nanimated
# ...                                                  ...
# 23659                               Cool and interesting
# 23660          Light load, open to your ideas, loves God
# 23661  Good prof., his readings are key, wants to see...
# 23662  Very insightful. His insights will really make...
# 23663                        sure B+/A if you're a woman
#
#                                                     cons  \
# 1445                                                none
# 1446                      the recordings are a bit vague
# 1447   Workload can be overwhelming. Always plan ahea...
# 1448                                    Sometimes boring
# 1449                                         inorganized
# ...                                                  ...
# 23659                                               None
# 23660                                              none.
# 23661  Sometimes classes can dissolve into rants abou...
# 23662  Super cranky. He will get mad when he sees som...
# 23663                               C/C+ if you're a guy
#
#                                                 comments  is_verified  \
# 1445             He's a new teacher but he'll get better            1
# 1446   It is fun to learn Japanese when she's the tea...            1
# 1447   A must take especially for those in the Humani...            1
# 1448   Average long tests, but you need to study hard...            1
# 1449    he tends to stutter but he makes biotech so fun!            1
# ...                                                  ...          ...
# 23659                                               none            1
# 23660  He's got a lot of experience. Although the sub...            1
# 23661  "He misses the mark" in a sense. At times it s...            1
# 23662                                                N/A            1
# 23663                          An empty-headed academic.            1
#
#        created_on   modified_on
# 1445   1338214314  1.338238e+09
# 1446   1338214713  1.338238e+09
# 1447   1338231188  1.338238e+09
# 1448   1338231214  1.338238e+09
# 1449   1338231261  1.338238e+09
# ...           ...           ...
# 23659  1483875396  1.484081e+09
# 23660  1483941256  1.484081e+09
# 23661  1483942865  1.484081e+09
# 23662  1483972642  1.484081e+09
# 23663  1484078517  1.484081e+09
#
# [15457 rows x 9 columns]

# %%
# display the DF's descriptive statistics
reviews_df.describe()
# Out:
#                  id       item_id   recommended   is_verified    created_on  \
# count  23680.000000  23680.000000  23680.000000  23680.000000  2.368000e+04
# mean   12635.190541    471.989738      0.849071      0.999324  1.363227e+09
# std     7308.819779    382.644899      0.357987      0.025986  4.283877e+07
# min        5.000000      1.000000      0.000000      0.000000  1.234568e+09
# 25%     6454.750000    193.000000      1.000000      1.000000  1.348602e+09
# 50%    12599.500000    405.000000      1.000000      1.000000  1.365389e+09
# 75%    18982.250000    591.000000      1.000000      1.000000  1.382757e+09
# max    25237.000000   2120.000000      1.000000      1.000000  1.488829e+09
#
#         modified_on
# count  1.545700e+04
# mean   1.380494e+09
# std    4.617084e+07
# min    1.338238e+09
# 25%    1.346188e+09
# 50%    1.365040e+09
# 75%    1.400334e+09
# max    1.484081e+09

# %%
compression_opts = dict(method='zip', archive_name='out.csv')

reviews_df.to_csv('out.zip', index=False, compression=compression_opts)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))

df_2 = reviews_df.groupby('recommended').count()
df_2.reset_index(inplace=True)
ax = sns.barplot(x='recommended', y='comments', data=df_2);
ax.set_title('\nComments on \nrecommended vs unrecommended professors\n', fontsize=25)

values = reviews_df['recommended'].value_counts()

for i, p in enumerate(ax.patches):
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, height, values[i], ha="center")

# %%
df_len = len(reviews_df)
mask = reviews_df['recommended'] == 1
rec_ct = int(reviews_df['recommended'].loc[mask].value_counts().values)

print(f'\ntotal comment count = {df_len}\ntotal recommendations count = {rec_ct}')
print(f'\nProbability that a comment is a recommendation = {(rec_ct / df_len) * 100:.4f}%')
print(f'Probability that a comment is a \'constructive\' criticism = {((df_len - rec_ct) / df_len) * 100:.4f}%\n')
# Out:
# total comment count = 23680
# total recommendations count = 20106
#
# Probability that a comment is a recommendation = 84.9071%
# Probability that a comment is a 'constructive' criticism = 15.0929%

# %%
# init tf-idf vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# vectorize the comments data
vectorized_X = vectorizer.fit_transform(reviews_df['comments'])

print('\nrows, features/words:')
vectorized_X.todense().shape
# Out:
# rows, features/words:
# (23680, 10706)

# %%
# split the vectorized data
train_X, test_X, train_Y, test_Y = train_test_split(vectorized_X, reviews_df["recommended"], train_size=0.3) 

print(train_X.shape, test_X.shape)
# Out:
# (7104, 10706) (16576, 10706)

# %%
from sklearn import LinearSVC

# init Scalable Linear SVM classifier
# classifier = SVC(kernel='linear')
classifier = LinearSVC()

# train Linear SVM classifier
classifier.fit(train_X.toarray(), train_Y)

# %%
# use cross validation to see how well a Linear SVM classifier would work on our data
scores = cross_val_score(classifier, test_X.toarray(), test_Y, cv=2)
acc = scores.mean()
print("Accuracy: %0.2f percent (+/- %0.2f)" % (acc *100, scores.std()))
scores
